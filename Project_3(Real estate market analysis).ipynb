# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Приведение-название-столбцов-в-соответствие" data-toc-modified-id="Приведение-название-столбцов-в-соответствие-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Приведение название столбцов в соответствие</a></span></li><li><span><a href="#Заполнение-пропусков-в-данных" data-toc-modified-id="Заполнение-пропусков-в-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Заполнение пропусков в данных</a></span></li><li><span><a href="#Приведение-типов-столбцов-в-соответствие" data-toc-modified-id="Приведение-типов-столбцов-в-соответствие-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Приведение типов столбцов в соответствие</a></span></li><li><span><a href="#Обработка-дубликатов" data-toc-modified-id="Обработка-дубликатов-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка дубликатов</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-времени-продажи-квартиры" data-toc-modified-id="Изучение-времени-продажи-квартиры-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение времени продажи квартиры</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Средняя-цена-квадратного-метра-в-10-наиболее-популярных-локациях" data-toc-modified-id="Средняя-цена-квадратного-метра-в-10-наиболее-популярных-локациях-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Средняя цена квадратного метра в 10 наиболее популярных локациях</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Определение-центра-Санкт-Петербурга-на-основании-данных" data-toc-modified-id="Определение-центра-Санкт-Петербурга-на-основании-данных-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Определение центра Санкт-Петербурга на основании данных</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Анализ-сегмента-квартир-в-центре-Санкт-Петербурга" data-toc-modified-id="Анализ-сегмента-квартир-в-центре-Санкт-Петербурга-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Анализ сегмента квартир в центре Санкт-Петербурга</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# <div style="background:#e5e5e5; color:#000; padding:10px">
#
# Привет еще раз!
#
# Все критические замечания устранены, отличная работа! Проект принят, ты молодец!
#
# Можно в вывод чуть больше конкретики добавить в сравнении квартир в центра и по всей базе.
#
# Желаю тебе успехов во всех будущих начинаниях! 🙂
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b> Комментарий от студента </b>
#
# Привет, меня зовут Кирилл. Предлагаю сразу перейти на "ты" для удобства общения. Свои комментарии по ходу проверки буду оставлять в подобной форме.
#
# Спасибо, что проверяете мой проект! Буду рад любым замечаниям и предложениям, успехов в работе!
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# Кирилл, привет!
#
# Меня зовут Сергей Кулешин, и я буду делать ревью твоего проекта. Давай будем общаться на «ты». Моя основная цель - не указать тебе на совершенные тобой ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
#
# Свои комментарии я буду выделять следующим образом:
# <div class="alert alert-danger">
#
#   <b>Комментарий ревьюера</b>
#
#   ❌ Так выделено то, что необходимо исправить, прежде чем я смогу принять твой проект.
# </div>
#
#
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Так отмечены не обязательные к доработке моменты. Mожешь учесть их при редактировании проекта. На твое усмотрение.
# </div>
#
#
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ А так удачные решения и подходы, на которые стоит опираться в будущих проектах.
# </div>
#
#
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Такой комментарий будет в конце тетрадки. В нем будут еще раз указаны нюансы, требующие обязательного исправления.
# </div>
#
# Предлагаю работать над проектом в форме диалога: если ты <b>что-то меняешь</b> в работе по моим рекомендациям — <b>напиши об этом</b> в ячейке `Markdown` и помечай комментарий каким-то заметным цветом, например так:
#
#
# ```
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
# ```
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
#
# Пожалуйста, <b>не перемещай, не изменяй и не удаляй мои комментарии</b>. Такой формат работы поможет выполнить повторную проверку твоего проекта оперативнее.
#
# <div style="background:#e5e5e5; color:#000; padding:10px">
#     <b>Общее впечатление о проекте</b>
#
# Ты верно провел исследование. Видно, что ты умеешь писать и применять функции, это здорово облегчает работу аналитика. В самой функции оставляй небольшое описание того, что она делает, так тебе или твоим колегам в будущем будет проще разобраться с кодом. Комментарии лучше оставлять сверху. Так-же в проекте есть моменты, которые требуют твоего внимания и доработки.
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
# Импортируем необходимые для работы библиотеки

import pandas as pd
import os
import sys
import matplotlib.pyplot as plt

# %%
# Читаем данные из полученного .csv файла и сохраняем в df
# Воспользуемся универсальной конструкцией для подгрузки файла как с сервера и локально

pth1 = 'real_estate_data.csv' #Локальный путь
pth2 = '/datasets/real_estate_data.csv' #Серверный путь

if os.path.exists(pth1):
    data = pd.read_csv(pth1)
elif os.path.exists(pth2):
    data = pd.read_csv(pth2)
else:
    print('Something is wrong. Check path')

# %%
# Выводим первые 5 строк датафрейма

data.head()
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...

# %% [markdown]
# Обращаем внимание, что разделителем в исходной таблице выступает символ табуляции. Добавим эту информацию к операции чтения данных из файла .csv

# %%
# Дописываем условие sep в операцию чтения файла

pth1 = '/datasets/real_estate_data.csv' #Локальный путь
pth2 = '/datasets/real_estate_data.csv' #Серверный путь

if os.path.exists(pth1):
    data = pd.read_csv(pth1, sep='\t')
elif os.path.exists(pth2, sep='\t'):
    data = pd.read_csv(pth2)
else:
    print('Something is wrong. Check path')

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Отличная загрузка! Так можно работать как локально, так и в окружении Практикума.
# </div>

# %%
# Выводим первые 5 строк датафрейма и общую информацию по таблице

display(data.head())
data.info()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Итак, рассмотрим полученные данные более детально.
#
# В таблице 22 колонки. Типы данных в столбцах: int, float, object, bool.
#
# Согласно полученной документации:
# * `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# * `balcony` — число балконов
# * `ceiling_height` — высота потолков (м)
# * `cityCenters_nearest` — расстояние до центра города (м)
# * `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# * `first_day_exposition` — дата публикации
# * `floor` — этаж
# * `floors_total` — всего этажей в доме
# * `is_apartment` — апартаменты (булев тип)
# * `kitchen_area` — площадь кухни в квадратных метрах (м²)
# * `last_price` — цена на момент снятия с публикации
# * `living_area` — жилая площадь в квадратных метрах (м²)
# * `locality_name` — название населённого пункта
# * `open_plan` — свободная планировка (булев тип)
# * `parks_around3000` — число парков в радиусе 3 км
# * `parks_nearest` — расстояние до ближайшего парка (м)
# * `ponds_around3000` — число водоёмов в радиусе 3 км
# * `ponds_nearest` — расстояние до ближайшего водоёма (м)
# * `rooms` — число комнат
# * `studio` — квартира-студия (булев тип)
# * `total_area` — площадь квартиры в квадратных метрах (м²)
# * `total_images` — число фотографий квартиры в объявлении
#
# Заметим, что в количество значений в столбцах разнится, что сведетельствует о наличии пропусков.

# %% [markdown]
# ### Вывод

# %% [markdown]
# В каждой строке таблицы — данные об объекте недвижимости. Таблица состоит из двух видов данных. Первые вписаны пользователем, вторые - получены автоматически на основе картографичемх данных.
#
# Предварительно можно утверждать, что данных достаточно для дальнейшей работы. Однако, в данных встречаются пропуски. Также необходимо проверить полученные данные на наличие аномалий, явных и неявных дубликатов.
#
# Чтобы двигаться дальше необходимо устранить проблемы в данных.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Приведение название столбцов в соответствие

# %% [markdown]
# Первым делом приведём в соответствие название столбцов в таблице.

# %%
# выводим названия столбцов в таблице

data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# В названиях слобцов присутствует несколько неточностей, которые стоит устранить:
# * `cityCenters_nearest` - приведем к "змеиному" регистру
# * `parks_around3000` - приведём к змеиному" регистру
# * `ponds_around3000` - приведём к змеиному" регистру

# %%
# Переименовываем столбцы и проверяем результат

data = data.rename(columns={'cityCenters_nearest': 'city_centers_nearest', 
                            'parks_around3000': 'parks_around_3000', 
                            'ponds_around3000': 'ponds_around_3000'})
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# ### Заполнение пропусков в данных

# %%
# Создаем переменную для расчета количества потерь при работе с пропусками

data_missing_nan = data.shape[0]

# %%
# Считаем количество пропущенных значений в таблице

#data.isna().sum()
round((data.isna().mean()*100),2)
# Out:
# total_images             0.00
# last_price               0.00
# total_area               0.00
# first_day_exposition     0.00
# rooms                    0.00
# ceiling_height          38.80
# floors_total             0.36
# living_area              8.03
# floor                    0.00
# is_apartment            88.29
# studio                   0.00
# open_plan                0.00
# kitchen_area             9.61
# balcony                 48.61
# locality_name            0.21
# airports_nearest        23.38
# city_centers_nearest    23.29
# parks_around_3000       23.28
# parks_nearest           65.91
# ponds_around_3000       23.28
# ponds_nearest           61.56
# days_exposition         13.42
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Проверять и на пропуски удобней так, тут показывает процент пропусков по столбцам:
# ```python
# round((data.isna().mean()*100),2)
# ```
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Поправил.
# </div>

# %% [markdown]
#
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Отлично!
# </div>

# %%
# Расчитаем долю пропущенных значений в ceiling_height

print('Доля пропущенных значение в столбце ceiling_height: ', 
      round(data['ceiling_height'].isna().sum() / data['total_images'].count(), 2) * 100, '%', end='')
# Out:
# Доля пропущенных значение в столбце ceiling_height:  39.0 %

# %% [markdown]
# В таблице обнаружено большое количество пропусков. Начинаем обработку последовательно.
#
# Рассмотрим пропуски в колонке `ceiling_height `. Пропуски в колонке, отвечающей за высоту полотка, могли возникнуть по причине не указания пользователем данного параметра, при создании объявления.
#
# Доля пропущенных значений в таблице высока (более 30%). Необходимо заменить пропущенные значения на среднее или медиану. Для этого расчитаем оба параметра, а также посмотрим максимальное и минимальное значение в данной колонке.

# %%
print('Среднее значение высоты потолка:', data['ceiling_height'].mean())
print('Медиана высоты потолка:', data['ceiling_height'].median())
print('Максимальное значение высоты потолока:', data['ceiling_height'].max())
print('Минимальное значение высоты потолка', data['ceiling_height'].min())
# Out:
# Среднее значение высоты потолка: 2.77149889685604
# Медиана высоты потолка: 2.65
# Максимальное значение высоты потолока: 100.0
# Минимальное значение высоты потолка 1.0

# %% [markdown]
# Заметим, что в исходном датафрейме присутствуют аномальные значения высоты потолка. Правильным решением в данной ситуации будет замена пропущенных значений на медиану. Это и сделаем.

# %%
# Заполняем пропущенные значения в столбце ceiling_height на медиану

data['ceiling_height'] = data['ceiling_height'].fillna(value=data['ceiling_height'].median())
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Заполнить пропуски медианой верное решение.
# </div>

# %% [markdown]
# Идем далее. Рассмотрим колонку `floors_total`. Расчитаем долю пропущенных значений.

# %%
print('Доля пропущенных значение в столбце floors_total: ', 
      round(data['floors_total'].isna().sum() / data['total_images'].count(), 3) * 100, '%', end='')
# Out:
# Доля пропущенных значение в столбце floors_total:  0.4 %

# %% [markdown]
# Доля пропущенных значений составляет всего 0.4%, поэтому имеем возможность удалить все строки с пропуском значния в данной колонке без существенного влияния на итоговый результат исследования.

# %%
# Удаляем строки с пропущенными значениями в столбце floors_total и проверяем результат

data = data.dropna(subset=['floors_total'])
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1870
# floor                       0
# is_apartment            20838
# studio                      0
# open_plan                   0
# kitchen_area             2231
# balcony                 11480
# locality_name              48
# airports_nearest         5532
# city_centers_nearest     5509
# parks_around_3000        5508
# parks_nearest           15568
# ponds_around_3000        5508
# ponds_nearest           14552
# days_exposition          3172
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Согласен.
# </div>

# %% [markdown]
# Рассмотрим колонку `living_area`. Согласно документации в этой колонке указана жилая площадь квартиры. Пропуски значений в этой колонке - это критично.
#
# Какие варианты решения можно предложить?
# * Можно проанализировать локацию, где находится квартира. В открытых источниках найти среднюю стоимость квадратного метра и приблизительно посчитать метраж квартиры, отталкиваясь от её стоимости в объявлении. Однако, данные могут быть сильно искажены в случае, если пользователь не знает цены квадратного метра и указал сумму значительно выше или ниже рыночной. Также для корректного расчета метража необходимо знать точное местоположение квартиры (геогр. координаты, например), т.к. цена квадратного метра в пределах Москвы или Санкт-Петербурга может отличаться более чем в 10 раз, в зависимости от района города.
# * Метраж - это один из целевых показателей в объявлении, поэтому заменить его на медианное или среднее значение однозначно является некорректным.
# * Можно посчитать общую долю строк с пропущенными значениями и, в случае небольшого процента, удалить все строки с пропусками.
# * Cтоит заметить. Что в исходном датафрейме также указаны: общая площадь квартиры, площадь кухни. Попробуем восстановить часть данных следующим образом: если в таблице указана общая площадь квартиры и площадь кухни, то расчитываем жилую площадь путем вычитания из общей площади площадь кухни.

# %%
# Расчитаем долю пропущенных значений в living_area

print('Доля пропущенных значение в столбце living_area: ', 
      round(data['living_area'].isna().sum() / data['living_area'].count(), 2) * 100, '%', end='')
# Out:
# Доля пропущенных значение в столбце living_area:  9.0 %

# %% [markdown]
# Доля значений пропущенных значения составляет менее 10%. Заполнение данного столбца, как уже было упомянуто ранее, не является корректным решением, т.к. можно внести существенное искажение итоговых результатов.
#
# Попробуем восстановить часть данных путем, описанным ранее.

# %%
# Заполняем пропущенные значения в столбце living_area и считаем количество пропусков

temp_column = data[(data['living_area'].isna()) & 
                   (~data['kitchen_area'].isna()) & 
                   (~data['total_area'].isna())]

data['living_area'] = data['living_area'].fillna(value=temp_column['total_area'] - temp_column['kitchen_area'])

print('Доля пропущенных значение в столбце living_area после обработки: ', 
      round(data['living_area'].isna().sum() / data['living_area'].count(), 2) * 100, '%', end='')
# Out:
# Доля пропущенных значение в столбце living_area после обработки:  6.0 %

# %% [markdown]
# Благодаря предложенному алгоритму удалось сохранить 3% ценных данных, путем самостоятельного расчета жилой площади. Оставшиеся 6% данных не имеют как минимум двух критически важных параметра из трех (общая площадь, жилая площадь, площадь кухни).
#
# Для более корректного исследования необходимо удалить данные строки.

# %%
# Удаляем строчки с пропущенными значения в столбце living_area

data = data.dropna(subset=['living_area'])
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment            19479
# studio                      0
# open_plan                   0
# kitchen_area              800
# balcony                 10296
# locality_name              44
# airports_nearest         5064
# city_centers_nearest     5043
# parks_around_3000        5042
# parks_nearest           14578
# ponds_around_3000        5042
# ponds_nearest           13633
# days_exposition          3064
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Не до конца согласен! Лучше попробовать восстановить данные жилой площади и далее площади кухни, разбив квартиры на группы (напирмер по количеству комнат), в каждой группе найти свое соотношение общей площади к жилой и провести замену по каждой группе отдельно.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Понял, учту в будущих проектах!
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ 👌
# </div>

# %% [markdown]
# Рассмотрим столбец `is_apartment`. Это столбец, хранящий в себе тип недвижимости: апартаменты или нет. Посмотрим какие значения присутствуют в таблице

# %%
# Выводим все уникальные значения столбца is_apartments

data['is_apartment'].unique()
# Out:
# array([nan, False, True], dtype=object)

# %% [markdown]
# Логично предположить, что значение в колонке `True` указывает на принадлежность недвижимости к типу "апартаменты". `False` - на отсутствие принадлежности.
#
# Можно предположить, что пропущенные значения в данном столбце вызваны незаполнением поля с типом недвижимости. Вероятно, что человек, выставляющий квартиру на продажу и имеющий не апартаменты - вовсе не будет заполнять данное поле.
#
# Если эта гипотеза верна, то стоит передать этот запрос разработчикам для уточнения формы заполнения. Например, при отсутствии галочки в чекбоксе "Апартаменты" должно автоматически передаваться значение `False`.
#
# Доля пропусков косвенно подтверждает данную гипотезу, т.к. общая доля апартаментов на рынке недвижимости (новостройки) составляет примерно 21% (согласно https://www.cian.ru/stati-stolichnye-shtuchki-polzujutsja-li-populjarnostju-apartamenty-306637/)
#
# Следуя данной версии заполняю пропущенные значения на  `False`. Будем считать, что пропущенные строчки в колонке `is_apartment` - не апартаменты.

# %%
# Заменяем пропущенные значения на 'False'

data['is_apartment'] = data['is_apartment'].fillna(value=False)
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area              800
# balcony                 10296
# locality_name              44
# airports_nearest         5064
# city_centers_nearest     5043
# parks_around_3000        5042
# parks_nearest           14578
# ponds_around_3000        5042
# ponds_nearest           13633
# days_exposition          3064
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Считаю так же! 👍
# </div>

# %% [markdown]
# Рассмотрим колонку `kitchen_area`. Согласно документации она содержит площадь кухни в квартире. Попробуем сохранить часть есть данных по аналогичной схеме.
#
# Расчитаем долю пропущенных данных

# %%
# Расчитаем долю пропущенных значений в kitchen_area

print('Доля пропущенных значение в столбце kitchen_area: ', 
      round(data['kitchen_area'].isna().sum() / data['kitchen_area'].count(), 2) * 100, '%', end='')
# Out:
# Доля пропущенных значение в столбце kitchen_area:  4.0 %

# %%
# Заполняем пропущенные значения в столбце kitchen_area и считаем количество пропусков

temp_column = data[(data['kitchen_area'].isna()) & 
                   (~data['living_area'].isna()) & 
                   (~data['total_area'].isna())]

data['kitchen_area'] = data['kitchen_area'].fillna(value=temp_column['total_area'] - temp_column['living_area'])

print('Доля пропущенных значение в столбце living_area после обработки: ', 
      round(data['living_area'].isna().sum() / data['living_area'].count(), 2) * 100, '%', end='')
data.isna().sum()
# Out:
# Доля пропущенных значение в столбце living_area после обработки:  0.0 %
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                 10296
# locality_name              44
# airports_nearest         5064
# city_centers_nearest     5043
# parks_around_3000        5042
# parks_nearest           14578
# ponds_around_3000        5042
# ponds_nearest           13633
# days_exposition          3064
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Можно по аналогии с жилой площадью сделать.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Понял, учту в будущих проектах!
# </div>

# %% [markdown]
# С помощью разработанного алгоритма удалось восстановить все данные в колонке `kitchen_area`.
#
# Далее рассмотрим колонку `balcony`. Данная колонка отвечает за количество балконов. Можно предположить, что пропущенные значения в данной колонке - это отсутствие балкона в квартире. Заполним все пропущенные значения в этом столбце на "0".

# %%
# Заполняем пропущенные значения в столбце balcony

data['balcony'] = data['balcony'].fillna(value=0)
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              44
# airports_nearest         5064
# city_centers_nearest     5043
# parks_around_3000        5042
# parks_nearest           14578
# ponds_around_3000        5042
# ponds_nearest           13633
# days_exposition          3064
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Логично.
# </div>

# %% [markdown]
# Согласно сопроводительной документации в колонке `locality_name` указано название населенного пункта. Восстановить данные не представляется возможным ввиду отсутствия географических координат объекта.
#
# Удаляем строки с пропущенными значениями.

# %%
# Удаление строк с пропущенными данными в locality_name

data = data.dropna(subset=['locality_name'])
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5057
# city_centers_nearest     5036
# parks_around_3000        5035
# parks_nearest           14548
# ponds_around_3000        5035
# ponds_nearest           13613
# days_exposition          3063
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ Тут можно еще попробовать вывести все уникальные названия населенных пунктов и посмотреть на неявные дубликаты, такие как: "деревня Кудрово" и "Кудрово" и т.п.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Сделал это в следующих разделах. Однако, не заметил данный дубликат. Учту!
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Хорошо.
# </div>

# %% [markdown]
# Переходим к обработке столбцов, которые, предположительно, были сформированны автоматически на основе данных, введенных пользователем.
#
# * `airports_nearest` - расстояние до ближайшего аэропорта в метрах (м)
# * `city_centers_nearest` - расстояние до центра города (м)
# * `parks_around_3000` - число парков в радиусе 3 км
# * `ponds_around_3000` число водоёмов в радиусе 3 км
# * `parks_nearest` - расстояние до ближайшего парка (м)
# * `ponds_nearest` - расстояние до ближайшего парка (м)
# * `days_exposition` - сколько дней было размещено объявление (от публикации до снятия)
#
# Пойдем по порядку. В колонках `airports_nearest`, `city_centers_nearest`, `parks_nearest`, `ponds_nearest` указано расстояние до целевой точки от объекта недвижимости. Рассмотрим столбцы, где данные пропущены.

# %%
# Выводим строки с пропущенными данными в столбце `airports_nearest`

data[data['airports_nearest'].isnull()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5                10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8                20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12               10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22               20   5000000.0       58.00  2017-04-24T00:00:00      2
# 38               10   3150000.0       40.00  2018-03-29T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23683            16   2100000.0       62.80  2018-09-18T00:00:00      4
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# Число пропусков в этих колонках примерно одинаково. Причиной появления пропусков может быть отсутствия данного функционала на момент получения данных от пользователя, либо сбой в результате которого данные по какой-то доли недвижимости не были получены.
#
# Информацию о потере данных стоит передать разработчикам.
#
# Какие есть варианты выхода из данной ситуации?
# * Оставить пропуски в данных
# * Заменить пропуски на целочисленное значение, однозначно характеризующее пропуск
#
# С целью полного избавления от пропусков исходного датафрейма заменим пропущенные значения в столбцах на "-1". При дальнейшем построении зависимостей отрежем отрицательные значения от общего пула.

# %%
# Заполняем пропущенные значения в столбцах 'airports_nearest', 'city_centers_nearest', 'ponds_nearest', 'parks_nearest'

list_columns = ['airports_nearest', 'city_centers_nearest', 'ponds_nearest', 'parks_nearest']

for i in list_columns:
    data[i] = data[i].fillna(value=-1)

data.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height             0
# floors_total               0
# living_area                0
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area               0
# balcony                    0
# locality_name              0
# airports_nearest           0
# city_centers_nearest       0
# parks_around_3000       5035
# parks_nearest              0
# ponds_around_3000       5035
# ponds_nearest              0
# days_exposition         3063
# dtype: int64

# %% [markdown]
# Рассмотрим значения в колонках `parks_around_3000` и `ponds_around_3000`. Данные столбцы описывают число парков и водоемов в указанном радиусе. Пропуски в данных колонках могут быть связаны с технической ошибкой, либо с отсутствием водоемов и парков поблизости. Гипотеза, подтверждающая наличие технической ошибки подкрепляется одинаковым количеством пропусков.
#
# Рассмотрим более детельно строки с пропусками.

# %%
# Выводим все строки, где отсутствуют значения в колонках parks_around_3000 и ponds_around_3000

data[data['parks_around_3000'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5                10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8                20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12               10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22               20   5000000.0       58.00  2017-04-24T00:00:00      2
# 38               10   3150000.0       40.00  2018-03-29T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23683            16   2100000.0       62.80  2018-09-18T00:00:00      4
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# Как уже оговаривалось ранее, строки с пропусками в колонках `parks_around_3000` и `ponds_around_3000` содержат в себе полезные для анализа данные, однако в них пропущенные данные по колонкам, заполняющимся автоматически на основе данных об объекте недвижимости.
#
# С целью не нарушения статистических данных, как и в прошлом примере, выставим вместо пропущенных значений флаг "-1", сигнализирующий нам о том, что в данных был пропуск.
#
# Замена значений на медианное, среднее или нулевое в данных колонках может привести к общему искажению результатов исследования. Исследования по данным направлениям, связанным с анализом водоёмов, парков, аэропортов поблизости объекта будем анализировать по тем строкам, где не было пропусков данных (не был установлен флаг "-1"). Таким образом мы получим более чистую и реальную картину.

# %%
# Заполняем пропущенные значения в столбцах parks_around_3000 и ponds_around_3000

list_columns = ['parks_around_3000', 'ponds_around_3000']

for i in list_columns:
    data[i] = data[i].fillna(value=-1)

data.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height             0
# floors_total               0
# living_area                0
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area               0
# balcony                    0
# locality_name              0
# airports_nearest           0
# city_centers_nearest       0
# parks_around_3000          0
# parks_nearest              0
# ponds_around_3000          0
# ponds_nearest              0
# days_exposition         3063
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Согласен, сами мы эти данные узнать не можем, значит надо оставить как есть, или поставить "заглушку".
# </div>

# %% [markdown]
# В столбце `days_exposition` (сколько дней было размещено объявление) пропуски в данных могут быть связаны с тем, что объявление на данный момент всё ещё опубликовано.
#
# Аналогично предыдущим примерам выставим вместо пропусков флаг "-1", сигнализирующий нам об этом.

# %%
# Заполняем пропущенные значения в столбце days_exposition

data['days_exposition'] = data['days_exposition'].fillna(value=-1)

print(data.isna().sum())
data.head(10)
# Out:
# total_images            0
# last_price              0
# total_area              0
# first_day_exposition    0
# rooms                   0
# ceiling_height          0
# floors_total            0
# living_area             0
# floor                   0
# is_apartment            0
# studio                  0
# open_plan               0
# kitchen_area            0
# balcony                 0
# locality_name           0
# airports_nearest        0
# city_centers_nearest    0
# parks_around_3000       0
# parks_nearest           0
# ponds_around_3000       0
# ponds_nearest           0
# days_exposition         0
# dtype: int64
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️  Как видно, большая часть пропущенных значений - в 2019 году. Больше половины объектов, выставленных на продажу в 2019 году не имеет рассчитанного "времени продажи квартиры". Скорее всего, пропуск в этой колонке означает, что объект не продан и объявление не закрыто. Я бы оставил как есть, не заменяя на заглушку.
#
# </div>

# %% [markdown]
# Итак, данные полностью очищены от пропусков с минимальными потерями.
#
# Расчитаем величину потери данных в результате работы с пропусками.

# %%
# Расчитываем величину потерь после удаления пропусков

print('Количество потерянных строк после работы с пропусками:', data_missing_nan - data.shape[0])
print('Процент потерянных строк:', round(((data_missing_nan - data.shape[0]) / data_missing_nan * 100), 2), '%')
# Out:
# Количество потерянных строк после работы с пропусками: 1561
# Процент потерянных строк: 6.59 %

# %% [markdown]
# **Выводы**
#
# Потери строк в результате работы над исходным датафремом не велики - менее 7%. Пропуски в таблице отсутствуют. Можно переходить к следующему этапу предобработки данных.

# %% [markdown]
# ### Приведение типов столбцов в соответствие

# %% [markdown]
# Ещё раз вглянем на информацию по датафрейму и первые 10 строк таблицы.

# %%
# Вывод основной информации по таблице и первые 10 строк

display(data.info())
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22138 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            22138 non-null int64
# last_price              22138 non-null float64
# total_area              22138 non-null float64
# first_day_exposition    22138 non-null object
# rooms                   22138 non-null int64
# ceiling_height          22138 non-null float64
# floors_total            22138 non-null float64
# living_area             22138 non-null float64
# floor                   22138 non-null int64
# is_apartment            22138 non-null bool
# studio                  22138 non-null bool
# open_plan               22138 non-null bool
# kitchen_area            22138 non-null float64
# balcony                 22138 non-null float64
# locality_name           22138 non-null object
# airports_nearest        22138 non-null float64
# city_centers_nearest    22138 non-null float64
# parks_around_3000       22138 non-null float64
# ...

# %% [markdown]
# Рассмотрим все столбцы датафрейма и проанализируем правильно выбора типа данных для конкретного столбца.
#
# * `total_images` - количество фотографий в объявлении. Данные представлены в типе int. Оставляем без изменений.
# * `last_price` - последняя цена в объявлении. Данные представлены в типе float. **Разумнее привести к типу int.**
# * `total_area` - общая площадь объекта. Данные представлены в типе float. Оставляем без изменений.
# * `first_day_exposition` - дата и время публикации объявления. Данные представлены в типе object. **Необходимо привести к типу datetime.**
# * `rooms` - количество комнат. Данные представлены в типе int. Оставляем без изменений.
# * `ceiling_height` - высота потолков. Данные представлены в типе float. Оставляем без изменений.
# * `floors_total` - количество этажей в доме. Данные представлены в типе float. **Разумнее привести к типу int.**
# * `living_area` - жилая площадь объекта. Данные представлены в типе float. Оставляем без изменений.
# * `floor` - этаж. Данные представлены в типе int. Оставляем без изменений.
# * `is_apartment` - является ли объект апартаментами. Данные представлены типом bool. Оставляем без изменений.
# * `studio` - является ли объект студией. Данные представлены типом bool. Оставляем без изменений.
# * `open_plan ` - присутствует ли в объекте свободная планировка. Данные представлены типом bool. Оставляем без изменений.
# * `kitchen_area ` - площадь кухни. Данные представлены в типе float. Оставляем без изменений.
# * `airports_nearest	` - расстояние до аэропорта. Данные представлены в типе float. **Разумнее привести к типу int.**
# * `city_centers_nearest` - расстояние до центра города. Данные представлены в типе float. **Разумнее привести к типу int.**
# * `parks_around_3000` - количество парков в радиусе 3000 метров. Данные представлены в типе float. **Разумнее привести к типу int.**
# * `parks_nearest` - расстояние до ближайшего парка. Данные представлены в типе float. **Разумнее привести к типу int.**
# * `ponds_around_3000` - количество водоёмов в радиусе 3000 метров. Данные представлены в типе float. **Разумнее привести к типу int.**
# * `ponds_nearest` - расстояние до ближайшего водоёма. Данные представлены в типе float. **Разумнее привести к типу int.**
# * `days_exposition` - сколько дней было размещено объявление. Данные представлены в типе float. **Разумнее привести к типу int.**
# * `locality_name ` - название локации. Данные представлены типом object. Оставляем без изменений.
#
# Почему было принято именно такое решение? Для столбцов, где подразумевается только возможность появление целочисленных чисел не имеет смысла представлять в типе float (например, этажность). Также столбцы, где трактовка и качество данных не исказится при отказе от типа данных float - также можно заменить на int (например, цена квартиры). Столбец с датой правильней будет представить в типе datetime, чтобы было удобнее работать с данным столбцом в дальнейшем.
#
# Следуем намеченному плану и переводим типы столбцов.

# %%
# Переводим типы столбцов в соответствие

to_int = ['airports_nearest', 
          'city_centers_nearest', 
          'parks_around_3000', 
          'parks_nearest', 
          'ponds_around_3000', 
          'ponds_nearest', 
          'days_exposition', 
          'floors_total', 
          'last_price']

for i in to_int:
    data[i] = data[i].astype('int')
    
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22138 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            22138 non-null int64
# last_price              22138 non-null int64
# total_area              22138 non-null float64
# first_day_exposition    22138 non-null object
# rooms                   22138 non-null int64
# ceiling_height          22138 non-null float64
# floors_total            22138 non-null int64
# living_area             22138 non-null float64
# floor                   22138 non-null int64
# is_apartment            22138 non-null bool
# studio                  22138 non-null bool
# open_plan               22138 non-null bool
# kitchen_area            22138 non-null float64
# balcony                 22138 non-null float64
# locality_name           22138 non-null object
# airports_nearest        22138 non-null int64
# city_centers_nearest    22138 non-null int64
# parks_around_3000       22138 non-null int64
# ...

# %%
# Переводим столбец `first_day_exposition` к типу datetime

data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y.%m.%d')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22138 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            22138 non-null int64
# last_price              22138 non-null int64
# total_area              22138 non-null float64
# first_day_exposition    22138 non-null datetime64[ns]
# rooms                   22138 non-null int64
# ceiling_height          22138 non-null float64
# floors_total            22138 non-null int64
# living_area             22138 non-null float64
# floor                   22138 non-null int64
# is_apartment            22138 non-null bool
# studio                  22138 non-null bool
# open_plan               22138 non-null bool
# kitchen_area            22138 non-null float64
# balcony                 22138 non-null float64
# locality_name           22138 non-null object
# airports_nearest        22138 non-null int64
# city_centers_nearest    22138 non-null int64
# parks_around_3000       22138 non-null int64
# ...

# %% [markdown]
# **Выводы**
#
# Все столбы датафрейма были приведены к соответствующим типам данных. Можно двигаться дальше.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Еще можно заменить тип данных у площадей с float64 на float32 для экономии памяти.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
#   ❌ Очень тяжело так отловить аномалии, мы же будем дальше строить гистограммы, по ним и увидим выбросы. А этот шаг лучше убрать.
#
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Убрал шаг с поиском аномалий путем вывода всех уникальных значений. Согласен с Вами, учту!
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ 👌 Мы же на "ты"!
#
# </div>

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# Проверим наш датафрейм на наличие дубликатов. Для этого посчитаем количество явных дубликатов и, если они будут найдены, удалим им.

# %%
# Подсчет количества дубликатов и приведение индексов строк в соответствие

display(data.duplicated().sum())
data = data.reset_index(drop=True)
# Out:
# 0

# %% [markdown]
# В таблице не было найдено ни одного дубликата.
#
# Предобработка данных полностью завершена, можно приступать к расчетам и исследованиям!

# %% [markdown]
# ### Выводы

# %% [markdown]
# В результате проделанной работы по предобработке данных была выполнена следующая работа:
# * Были определены пропущенные значения
# * Были заполненны пропущенные значения
# * Были приведены типы данных в соответствие
# * Были приведены названия столбцов в соответствие
# * Были обработаны аномалии в исходном датафрейма
# * Было произведена проверка на наличие дубликатов
# * Были даны необходимые пояснения ко всем шагам предобработки
#
# Общее доля потерянных строк составила не более 10% от исходных данных.
#
# Данные полностью обработаны и можно присутупать к расчетной части проекта.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Добавим к таблице необходимые расчетные данные, которые будут интересны нам в дальнейших исселедованиях.
#
# Что предстоит добавить в рамках расчетной части проекта:
# * Цену квадратного метра
# * День недели, месяц и год публикации объявления
# * Этаж квартиры (последний, первый, другой)
# * Соотношение жилой площади к общей
# * Соотношение площади кухни к общей

# %%
# Добавим к исходной таблице дополнительное поле с ценой квадратного метра
# Квадратные метры будем считать путем деления стоимость объекта на его общую площадь

data['meter_cost'] = data['last_price'] / data['total_area']
data['meter_cost'] = data['meter_cost'].astype('int')
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             2    10000000       100.0           2018-06-19      2
# 4            10     2890000        30.4           2018-09-10      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            3.03            14         32.0     13         False  ...
# 4            2.65            12         14.4      5         False  ...
#
#    balcony              locality_name  airports_nearest  city_centers_nearest  \
# ...

# %%
# Добавим столбцы с указанием дня недели, месяца, года публикации объявления

data['day'] = pd.DatetimeIndex(data['first_day_exposition']).weekday
data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month
data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year

data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             2    10000000       100.0           2018-06-19      2
# 4            10     2890000        30.4           2018-09-10      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            3.03            14         32.0     13         False  ...
# 4            2.65            12         14.4      5         False  ...
#
#    city_centers_nearest  parks_around_3000  parks_nearest  ponds_around_3000  \
# ...

# %%
# Напишем функцию, определяющую вариант этажа из перечня: первый, последний, другой

def floor_selection(row):
    try:
        if row['floor'] == 1:
            return 'первый'
        if row['floor'] == row['floors_total']:
            return 'последний'
        return 'другой'
    except:
        return (print('Something wrong, check func FLOOR_SELECTION'))

data['floor_type'] = data.apply(floor_selection, axis=1)

# %%
# Посчитаем отношения жилой площади к общей, а также площади к общей

data['living_to_total_area'] = round((data['living_area'] / data['total_area']), 3)
data['kitchen_to_total_area'] = round((data['kitchen_area'] / data['total_area']), 3)
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             2    10000000       100.0           2018-06-19      2
# 4            10     2890000        30.4           2018-09-10      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 3            3.03            14         32.0     13         False  ...
# 4            2.65            12         14.4      5         False  ...
#
#    ponds_around_3000  ponds_nearest  days_exposition  meter_cost day  month  \
# ...

# %% [markdown]
# ### Выводы
#
# В результате работы были категоризованы данные по этажам, было расчитано отношение площади кухни и жилой к общей, а также были добавлены столбцы с днем недели, месяцев и годом публикации объявления.
#
# Все необходимые данные для исследовательской части получены. Можно двигаться дальше!

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Дополнительные столбцы добавлены.  👍
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Первым делом построим гистограммы по основным параметрам: площадь, цена, число комнат, высота потолков

# %%
# Построим гистограммы для общей площади, а также для отношений жилой площади и кухни к общей площади

data['total_area'].hist(bins=30, range=(0, 300), alpha=0.55, facecolor='r')
plt.title('Гистограмма распределения общей площади объектов')
plt.xlabel('Площадь помещения')
plt.ylabel('Количество объектов')
plt.show()

data['living_to_total_area'].hist(bins=30, range=(0, 1), alpha=0.55, facecolor='g')
plt.title('Гистограмма отношения жилой площади к общей')
plt.xlabel('Величина отношения')
plt.ylabel('Количество объектов')
plt.show()

data['kitchen_to_total_area'].hist(bins=30, range=(0, 1), alpha=0.75)
plt.title('Гистограмма отношения кухонной площади к общей')
plt.xlabel('Величина отношения')
plt.ylabel('Количество объектов')
plt.show()

# %% [markdown]
# Глядя на построенные диаграммы можно сделать следующие выводы:
# * Наиболее часто встречающаяся общая площадь находится в диапазоне от 40 до 70 квадратных метров.
# * Наиболее распространенное отношение жилой площади к общей находится в диапазоне от 0.4 до 0.8.
# * Наиболее распространенное отношение площади кухни к общей находится в диапазоне от 0.1 до 0.3.
# * Распределение является нормальным.

# %%
# Построим гистаграмму по цене объектов

data['last_price'].hist(bins=30, alpha=0.40, facecolor='black', range=(0, 20000000))
plt.title('Гистаграмма цен объектов')
plt.xlabel('Цена объекта')
plt.ylabel('Количество объектов')
plt.show()

# %% [markdown]
# Глядя на данную диаграмму делаем следующие выводы:
# * Наиболее встречающаяся цена на объекты - от 3 до 6 миллионов.
# * Распределение является нормальным.
# * Цены выше 17 миллионов и ниже 2 миллионов встречаются довольно редко.

# %%
# Построим гистаграмму по количеству комнат

data['rooms'].hist(bins=10, alpha=0.70, facecolor='y', range=(0, 10))
plt.title('Гистаграмма распределения количества комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Количество объектов')
plt.show()

# %% [markdown]
# Выводы по данному графику следующие:
# * В основном, в объявлениях продаются 1, 2, 3, 4 комнатные квартиры. Квартиры с большим числом комнат встречаются редко.

# %%
# Построим гистаграмму по высоте потолков

data['ceiling_height'].hist(bins=15, alpha=0.70, facecolor='orange', range=(2.2, 4))
plt.title('Гистограмма распределения высоты потолков')
plt.xlabel('Высота потолков')
plt.ylabel('Количество объектов')
plt.show()

# %% [markdown]
# По данному графику можно заметить следующее:
# * Наиболее часто встречающаяся высота потолка - 2.65 метра. Связано это может быть с ГОСТ на строительство жилых домов, а также с большим числом пропусков в данном столбце. На прошлых шагах мы заменяли пропущенные значения на медианное. Это могло внести некоторые погрешности в данную гистограмму.
# * Высота потолков более 3 метров встречается редко.

# %% [markdown]
# ### Изучение времени продажи квартиры
#
# Построим гистограмму, демонстрирующее время продажи квартир.

# %%
# Построение гистограммы времени продажи квартир

data['days_exposition'].hist(bins=30, alpha=0.6, facecolor='blue')
plt.title('Гистограмма распределения времени продажи квартир')
plt.xlabel('Время продажи квартиры')
plt.ylabel('Количество объектов')
plt.show()

# %%
# Посчитаем среднее и медиану, предварительно отфильровав таблицу от значений "-1"

data_filtred = data.query('days_exposition >= 0')
print('Среднее время продажи квартиры: ', int(data_filtred['days_exposition'].mean()), 'дней (дня)')
print('Медианное время продажи квартиры: ', int(data_filtred['days_exposition'].median()), 'дней (дня)')
data_filtred['days_exposition'].describe()
# Out:
# Среднее время продажи квартиры:  184 дней (дня)
# Медианное время продажи квартиры:  100 дней (дня)
# count    19075.000000
# mean       184.677484
# std        221.796775
# min          1.000000
# 25%         44.000000
# 50%        100.000000
# 75%        238.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Какие выводы можно сделать?
# * Квартиры, проданные менее чем за 44 дня можно считать очень быстро проданными
# * Квартиры, проданные более чем за 238 дней можно считать необычно долгими
#
# Отфильтруем таблицу. Уберем редкие и выбивающиеся значения.

# %%
# Строим гистограмму по отфильтрованным значениям

data_filtred = data.query('days_exposition >= 0 & days_exposition <= 800')
print('Среднее время продажи квартиры: ', int(data_filtred['days_exposition'].mean()), 'дней (дня)')
print('Медианное время продажи квартиры: ', int(data_filtred['days_exposition'].median()), 'дней (дня)')
data_filtred['days_exposition'].describe()
# Out:
# Среднее время продажи квартиры:  159 дней (дня)
# Медианное время продажи квартиры:  95 дней (дня)
# count    18508.000000
# mean       159.061217
# std        166.544834
# min          1.000000
# 25%         43.000000
# 50%         95.000000
# 75%        217.000000
# max        800.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# В результате фильтрации значения медианы и среднего снизилось. Первый квартиль остался без изменения, третий квартиль оказался смещен в меньшую сторону.
#
# #### Выводы
# Какие выводы можно сделать после фильтрации?
# * Квартиры, проданные менее чем за 43 дня можно считать очень быстро проданными
# * Квартиры, проданные более чем за 217 дней можно считать необычно долгими

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
#   ❌ Вот тут, при анализе гистограмм и надо обрезать выбросы! А от у нас осталась и площадь в 900м. и комнат 19, и потолок высотой в 32 метра 🙂 (см. ниже)
#
#   ❌ И дальше вся корреляция очень плохо считается из-за наличия этих выбросов. Почисть их и пересчитай корреляцию.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Поправил, добавил фильтрацию далее
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Отлично! Так правильней! 👍
#
# </div>

# %%
data['rooms'].describe()
# Out:
# count    22138.000000
# mean         2.072003
# std          1.078716
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
data['total_area'].describe()
# Out:
# count    22138.000000
# mean        60.261800
# std         35.203089
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.800000
# max        900.000000
# Name: total_area, dtype: float64

# %%
data['ceiling_height'].describe()
# Out:
# count    22138.000000
# mean         2.727381
# std          1.020932
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Как мы видим, в данных просутствуют выбросы. Избавимся от них, руководствуясь нормативной документацией и здравым смыслом.
#
# Согласно СНиП 31-01-2003 (retrieved by: https://docs.cntd.ru/document/456054198), высота потолка должна быть не менее 2.5 метров. Допустим, что в данные присутствует элитное жилье, где высота потолков выше среднего. Будем считать, что максимальная высота потолка - 3.5 метра.
#
# Избавимся от выбросов в колонке с числом комнат. Будем исследовать объекты, где число комнат не превышает 5. Квартиры с числом комнат более 5 являются редкими на рынке недвижимости и некорректно будет учитывать их в наших исследования, т.к. они могут оказать сильное влияние на общий пул результатов.
#
# Также избавимся от выбросов в площади помещения. Будем отталкиваться, что согласно требованиям СП 54.13330.2011 площадь жилой комнаты не может быть менее 9 квадратных метров при условии, что в квартире есть еще одна жилая комната площадью 16 квадратных метров. Для однокомнатной же квартиры площадь единственной комнаты не может быть менее 14 квадратных метров. Заложим значение 14 метров в качестве минимального, а в качестве максимального значения заложим 280 квадратных метров, т.к. разброс площади у пятикомнатных квартир, чаще всего, находится в диапазоне от 110 до 280 квадратных метров (retrieved by: https://planvsem.ru/kvartira/planirovka-5-komnatnyh-kvartir.htm).

# %%
# Выполним очистку данных от выбросов

data_filtred = data.query('rooms <= 5 and 14 <= total_area <= 280 and 2.5 <= ceiling_height <= 3.5')

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры

# %%
# Определение фактора влияния площади на цену

data_filtred.plot(x='last_price', 
          y='total_area', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(0, 500), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и квадратными метрами:', round(data_filtred['last_price'].corr(data_filtred['total_area']), 3))
plt.title('Влияние площади на цену')
plt.xlabel('Цена')
plt.ylabel('Общая площадь')
plt.show()
# Out:
# Коэффициент Пирсона между ценой и квадратными метрами: 0.662

# %% [markdown]
# **Вывод**
#
# Коэффициент Пирсона и построенный нами график даёт некоторое понимаение зависимости цены от площади недвижимости.
#
# * Коэффициент Пирсона положителен и больше 0.5, следовательно, величины связаны.
# * График имеет наклонный вид, характеризующий положительную зависимость величин.

# %%
# Определение фактора влияния количества комнат на цену

data_filtred.plot(x='last_price', 
          y='rooms', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(0, 10), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и количеством комнат:', round(data_filtred['last_price'].corr(data_filtred['rooms']), 3))
plt.title('Влияние количества комнат на цену')
plt.xlabel('Цена')
plt.ylabel('Количество комнат')
plt.show()
# Out:
# Коэффициент Пирсона между ценой и количеством комнат: 0.361

# %% [markdown]
# **Вывод**
#
# Что можно понять по данному графику:
# * Горизональные линии распределены по оси X неравномерно, следовательно, величины зависят друг от друга.
# * Коэффициент Пирсона также является положительным, однако, менее 0.5. Можно делать вывод, что связь между величинами не сильная

# %%
# Определение фактора влияния удаленности от центра на цену

data_filtered = data.query('city_centers_nearest >= 0')

data_filtered.plot(x='last_price', 
          y='city_centers_nearest', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(0, 70000), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и удаленностью от центра:', round(data_filtered['last_price']
                                                                      .corr(data_filtered['city_centers_nearest']), 3))
plt.title('Влияние расстояния до центра на цену')
plt.xlabel('Цена')
plt.ylabel('Расстояние до центра (метров)')
plt.show()
# Out:
# Коэффициент Пирсона между ценой и удаленностью от центра: -0.203

# %% [markdown]
# **Вывод**
#
# Делаем следующие выводы согласно данному графику и расчету:
# * Наблюдается зависимость цены от удаленности от центра, но, в основном, на преодолении отметки цены в 10 млн.
# * Коэффициент Пирсона говорит о небольшой обратной зависимости.

# %%
# Определение фактора влияния месяца/года/дня недели на цену
# Поочередно строим матрицы

data_filtred.plot(x='last_price', 
          y='day', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(-1, 7), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и днем:', round(data_filtred['last_price']
                                                                      .corr(data_filtred['day']), 3))
plt.title('Зависимость цены от дня')
plt.xlabel('Цена')
plt.ylabel('День')
plt.show()
# Out:
# Коэффициент Пирсона между ценой и днем: -0.009

# %% [markdown]
# **Вывод**
#
# Согласно расчетам и графику - между днем публикации объявления и ценой зависимости нет. Коэффициент Пирсона равен нулю.

# %%
# Определение фактора влияния месяца/года/дня недели на цену
# Поочередно строим матрицы

data_filtred.plot(x='last_price', 
          y='year', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(2013, 2020), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и годом:', round(data_filtred['last_price']
                                                                      .corr(data_filtred['year']), 3))
plt.title('Зависимость цены от года')
plt.xlabel('Цена')
plt.ylabel('Год')
plt.show()
# Out:
# Коэффициент Пирсона между ценой и годом: -0.04

# %% [markdown]
# **Вывод**
#
# Согласно расчетам и графику - между годом публикации объявления и ценой зависимости нет. Коэффициент Пирсона практически равен нулю.

# %%
# Определение фактора влияния месяца/года/дня недели на цену
# Поочередно строим матрицы

data_filtred.plot(x='last_price', 
          y='month', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(-1, 13), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и месяцем:', round(data_filtred['last_price']
                                                                      .corr(data_filtred['month']), 3))
plt.title('Зависимость цены от месяца')
plt.xlabel('Цена')
plt.ylabel('Месяц')
plt.show()
# Out:
# Коэффициент Пирсона между ценой и месяцем: -0.003

# %% [markdown]
# **Вывод**
#
# Согласно расчетам и графику - между месяцем публикации объявления и ценой зависимости нет. Коэффициент Пирсона практически равен нулю.

# %%
# Строим диаграмму рассеяния по этажу и цене

def is_floor_type_id(floor):
    try:
        if floor == 'первый':
            return 0
        elif floor == 'другой':
            return 1
        elif floor == 'последний':
            return 2
        else:
            print('Something wrong...')
    except:
        return (print('Проверьте функцию floor_type_id'))
    
data_filtred['floor_type_id'] = data_filtred['floor_type'].apply(is_floor_type_id)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()

# %%
data_filtred.plot(x='last_price', 
          y='floor_type_id', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(-1, 3), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и квадратными метрами:', round(data_filtred['last_price']
                                                                      .corr(data_filtred['floor_type_id']), 3))
# Out:
# Коэффициент Пирсона между ценой и квадратными метрами: 0.047

# %% [markdown]
# **Вывод**
#
# Согласно расчетам и графику - между этажем объекта и ценой зависимости практически нет. Коэффициент Пирсона практически равен нулю.

# %% [markdown]
# #### Выводы
#
# Итак, подводим итоги по анализу зависимости цены от перечня характеристик объекта.
#
# Наблюдается зависимость между:
# * Ценой и метражем объекта
# * Ценой и количеством комнат
# * Ценой и удаленностью от центра
#
# Зависимость отсутствует между:
# * Датой размещения объявления и ценой
# * Этажем объекта и ценой

# %% [markdown]
# ### Средняя цена квадратного метра в 10 наиболее популярных локациях

# %% [markdown]
# ***Задача:***
#
# - Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`
#
#
# Приступаем к выполнению!

# %%
# Производим выборку 10 самых частовстречающихся населенных пунктов

data_filtred['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург      14348
# посёлок Мурино         479
# посёлок Шушары         407
# Всеволожск             369
# Пушкин                 336
# Колпино                326
# посёлок Парголово      301
# Гатчина                294
# деревня Кудрово        267
# Петергоф               197
# Name: locality_name, dtype: int64

# %%
# Делаем копию датафрема и создаем список с названием локаций
data_locality = data_filtred.copy()
locality_top_10 = ['Санкт-Петербург', 
                   'посёлок Мурино', 
                   'посёлок Шушары', 
                   'Всеволожск', 
                   'Пушкин', 
                   'Колпино', 
                   'посёлок Парголово', 
                   'Гатчина', 
                   'деревня Кудрово', 
                   'Выборг']

# Сегментируем созданный датафреййм по locality_top_10
data_locality = data_locality.query('@locality_top_10 in locality_name')

# Создаем pivot_table
data_locality = data_locality.pivot_table(index=['locality_name'], 
                                          values='meter_cost', 
                                          aggfunc='mean').sort_values(by='meter_cost', ascending=False).reset_index().round(1)
# Переименовываем столбы
data_locality = data_locality.rename(
            columns={
                'locality_name': 'Название населенного пункта',
                'meter_cost': 'Цена за квадратный метр (руб)',
            }
)

display(data_locality)
# Out:
#   Название населенного пункта  Цена за квадратный метр (руб)
# 0             Санкт-Петербург                       113199.5
# 1                      Пушкин                       102961.9
# 2             деревня Кудрово                        92606.0
# 3           посёлок Парголово                        90414.0
# 4              посёлок Мурино                        86160.5
# 5              посёлок Шушары                        78740.5
# 6                     Колпино                        75268.9
# 7                  Всеволожск                        68898.0
# 8                     Гатчина                        68751.2
# 9                      Выборг                        58364.5

# %% [markdown]
# #### Выводы
#
# Согласно полученным данным:
# * Наибольшая средняя цена за квадратный метр в Санкт-Петербурге - 113199 тыс. руб
# * Наименьшая средняя цена за квадратный метр в Выборге - 58364 тыс. руб

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Логично, что в Питере дороже всего.
# </div>

# %% [markdown]
# ### Определение центра Санкт-Петербурга на основании данных

# %%
# Создаем копию исходного датафрейма
data_spb = data_filtred.copy()
spb = 'Санкт-Петербург'

# Сегментируем созданный датафрейм по locality_top_10
data_spb = data_spb.query('@spb in locality_name') 

# Переводим метры в километры и округляем до целого
data_spb['city_centers_nearest'] = (data_spb['city_centers_nearest'] / 1000).astype('int')

# Создаем pivot_table
data_spb = data_spb.pivot_table(index=['city_centers_nearest'], 
                                          values='meter_cost', 
                                          aggfunc='mean').sort_values(by='city_centers_nearest', ascending=False).reset_index().round(1)

# Переименовываем столбы
data_spb = data_spb.rename(
            columns={
                'city_centers_nearest': 'Расстояние до центра (км)',
                'meter_cost': 'Цена за квадратный метр (руб)',
            }
)

# Строим график
data_spb.plot(x='Расстояние до центра (км)', y='Цена за квадратный метр (руб)', figsize=(10, 5), xlim=(0, 25))

#Выводим сводную таблицу
data_spb
# Out:
#     Расстояние до центра (км)  Цена за квадратный метр (руб)
# 0                          29                        65459.5
# 1                          28                        81840.2
# 2                          27                       132115.0
# 3                          26                        75171.3
# 4                          25                        90903.0
# 5                          24                        82824.9
# 6                          23                        93003.0
# 7                          22                        88742.3
# 8                          21                        91067.1
# 9                          20                       106700.6
# 10                         19                        95434.0
# 11                         18                        94929.6
# 12                         17                        94796.8
# 13                         16                       100121.3
# ...

# %% [markdown]
# #### Выводы
#
# Согласно полученной сводной таблице и графику можем сделать вывод:
# * Резкое увеличение цены за квадратный метр начинается расстояния 7 км до центра. Будем считать, что недвижимость, находящаяся в пределах 7 километров находится в центре города.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Да, 7км. похоже на центр. 👍
# </div>

# %% [markdown]
# ### Анализ сегмента квартир в центре Санкт-Петербурга

# %% [markdown]
# **Задача:**
# - «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
#
# Приступаем к выполнению!

# %%
# Сегментируем исходный датафрейм по критерию центра Санкт-Петербурга

data_spb_center = data_filtred.copy()
data_spb_center['city_centers_nearest'] = (data_spb_center['city_centers_nearest'] / 1000).astype('int')
data_spb_center = data_spb_center.query('locality_name == @spb & city_centers_nearest <= 7').reset_index(drop=True)

# %%
# Построим гистограммы для общей площади, а также для отношений жилой площади и кухни к общей площади
data_spb_center['total_area'].hist(bins=30, range=(0, 300), alpha=0.55, facecolor='r')
plt.title('Гистограмма распределения общей площади объектов')
plt.xlabel('Площадь помещения')
plt.ylabel('Количество объектов')
plt.show()

data_spb_center['living_to_total_area'].hist(bins=30, range=(0, 1), alpha=0.55, facecolor='g')
plt.title('Гистограмма отношения жилой площади к общей')
plt.xlabel('Величина отношения')
plt.ylabel('Количество объектов')
plt.show()

data_spb_center['kitchen_to_total_area'].hist(bins=30, range=(0, 1), alpha=0.75)
plt.title('Гистограмма отношения кухонной площади к общей')
plt.xlabel('Величина отношения')
plt.ylabel('Количество объектов')
plt.show()

# Построим гистаграмму по цене объектов
data_spb_center['last_price'].hist(bins=30, alpha=0.40, facecolor='black', range=(0, 30000000))
plt.title('Гистаграмма цен объектов')
plt.xlabel('Цена объекта')
plt.ylabel('Количество объектов')
plt.show()

# Построим гистаграмму по количеству комнат
data_spb_center['rooms'].hist(bins=10, alpha=0.70, facecolor='y', range=(0, 10))
plt.title('Гистаграмма распределения количества комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Количество объектов')
plt.show()

# Построим гистаграмму по высоте потолков
data_spb_center['ceiling_height'].hist(bins=15, alpha=0.70, facecolor='orange', range=(2.2, 4))
plt.title('Гистограмма распределения высоты потолков')
plt.xlabel('Высота потолков')
plt.ylabel('Количество объектов')
plt.show()

# %%
# Определение фактора влияния площади на цену
data_spb_center.plot(x='last_price', 
          y='total_area', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(0, 500), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и квадратными метрами:', round(data_spb_center['last_price'].corr(data_spb_center['total_area']), 3))
plt.title('Влияние площади на цену')
plt.xlabel('Цена')
plt.ylabel('Общая площадь')
plt.show()

# Определение фактора влияния количества комнат на цену
data_spb_center.plot(x='last_price', 
          y='rooms', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(0, 10), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и количеством комнат:', round(data_spb_center['last_price']
                                                                     .corr(data_spb_center['rooms']), 3))
plt.title('Влияние количества комнат на цену')
plt.xlabel('Цена')
plt.ylabel('Количество комнат')
plt.show()

# Определение фактора влияния удаленности от центра на цену
data_filtered = data_spb_center.query('city_centers_nearest >= 0')

data_filtered.plot(x='last_price', 
          y='city_centers_nearest', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(-1, 8), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и удаленностью от центра:', round(data_filtered['last_price']
                                                                      .corr(data_filtered['city_centers_nearest']), 3))
plt.title('Зависимость цены от удаленности от центра')
plt.xlabel('Цена')
plt.ylabel('Расстояние от центра (км)')
plt.show()
# Out:
# Коэффициент Пирсона между ценой и квадратными метрами: 0.614
# Коэффициент Пирсона между ценой и количеством комнат: 0.284
# Коэффициент Пирсона между ценой и удаленностью от центра: -0.081

# %%
# Определение фактора влияния месяца/года/дня недели на цену
# Поочередно строим матрицы
data_spb_center.plot(x='last_price', 
          y='day', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(-1, 7), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и днём:', round(data_spb_center['last_price']
                                                                      .corr(data_spb_center['day']), 3))
plt.title('Зависимость цены от дня')
plt.xlabel('Цена')
plt.ylabel('День недели')
plt.show()

data_spb_center.plot(x='last_price', 
          y='year', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(2013, 2020), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и годом:', round(data_spb_center['last_price']
                                                                      .corr(data_spb_center['year']), 3))
plt.title('Зависимость цены от года')
plt.xlabel('Цена')
plt.ylabel('Год')
plt.show()

data_spb_center.plot(x='last_price', 
          y='month', 
          kind='scatter', 
          figsize=(10,7), 
          xlim=(0, 30000000), 
          ylim=(-1, 13), 
          alpha=0.1)
print('Коэффициент Пирсона между ценой и месяцем:', round(data_spb_center['last_price']
                                                                      .corr(data_spb_center['month']), 3))
plt.title('Зависимость цены от месяца')
plt.xlabel('Цена')
plt.ylabel('Месяц')
plt.show()
# Out:
# Коэффициент Пирсона между ценой и днём: -0.005
# Коэффициент Пирсона между ценой и годом: -0.033
# Коэффициент Пирсона между ценой и месяцем: -0.031

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера</b>
#
#   ⚠️ После очистки выбросов и тут могут немного измениться результаты, подправить выводы надо.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Готово, результаты немного именились, но на выводы не повлияло.
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Да, общие выводы остались верными.
#
# </div>

# %% [markdown]
# #### Выводы
#
# Сделаем выводы, касательно отличий основных параметров общего пула квартир от квартир, расположенных в центре Санкт-Петербурга:
# * Влияние факторов относительно общего пула данных практически не изменилось
# * Единственным отличием результатов стало увеличения разброса и среднего значения высоты потолков в объектах, расположенных в центре Санкт-Петербурга

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В результате работы были получены следующие заключения:
# * В результате изучения времени продажи квартир можно сделать вывод, что квартиры, проданные менее, чем за 43 дня можно считать очень быстро проданными, а квартиры, проданные более чем за 217 продавались необычно долго.
# * В результате анализа влияния факторов, влияющих на стоимость объекта можно утверждать, что вне зависимости от расположения квартиры наибольшее влияние на ее стоимость оказывают: метраж, количество комнат и удаленность от центра, а наименьшее влияние на ее стоимость оказывают этажность объекта и дата публикации объявления.
# * В результате анализа 10 населенных пунктов с наибольшим числом объявлений было определено, что наибольшая стоимость квадратного метра у объектов в Санкт-Петербурге (113 тыс. руб / кв. м), а наименьшая стоимость в Выборге (58 тыс. руб / кв. м).
# * Был определен условный центра Санкт-Петербурга. На основании данных резкое увеличение цены наблюдается в радиусе 7 км от центра города. Можно утверждать, что объект находится в центре, если он расположен в радиусе 7 км от центра Санкт-Петербурга.
# * Был выполнен сравнительный анализ квартир, расположенных в центре Санкт-Петербурга, относительно остальных объектов. Особых отличий обнаружено не было. Единственным весомым отличием является значения высоты потолков. У квартир, расположенных в центре высота потолков выше.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера</b>
#
#   ❌ В общий вывод пишут не что сделали, а что определили - результаты. А еще нас просят сравнить данные по квартирам в центре и определить отличия от квартир по всей базе.
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Готово, выводы поправил.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ⚠️ Можно чуть больше конкретики добавить в сравнении квартир в центра и по всей базе. Например средняя площадь в центре - такая-то по все базе - такая-то, и т.д.
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Пересмотреть определение и удаление выбросов используя для этого гистограммы.
#
#   📃 Переписать общий вывод.
#
#
# Жду твой проект на повторное ревью. Не стесняйся оставлять комментарии и задавать вопросы. Удачи! Все получится 🙂
# </div>
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Все замечания поправил, на.
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [ ]  есть общий вывод
